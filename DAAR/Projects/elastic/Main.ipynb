# %%
import pandas as pd

# %%
df = pd.read_csv("./file/data.csv") # or the name of your file

# %%
df.head()
# Out:
#       CAMIS                   DBA      BORO BUILDING               STREET  \
# 0  50088984         NATURAL BLEND  Brooklyn      243  MALCOLM X BOULEVARD
# 1  50044265  NEW TASTE RESTAURANT    Queens     9462           CORONA AVE
# 2  50118550        CONCEPT COFFEE    Queens     4461              11TH ST
# 3  50033431     LEBRON RESTAURANT  Brooklyn    1567A        PITKIN AVENUE
# 4  41278255           METRO DINER    Queens    73-24  METROPOLITAN AVENUE
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  11233.0  3473782440           Caribbean      07/15/2022
# 1  11373.0  7185928738             Chinese      10/31/2023
# 2  11101.0  6463279517          Coffee/Tea      05/08/2024
# 3  11212.0  7183429070             Spanish      04/01/2022
# 4  11379.0  7183267402            American      07/09/2024
#
#                                             ACTION  ...  \
# 0  Violations were cited in the following area(s).  ...
# ...

# %%
res = df.groupby(by="NTA").size().reset_index(name='count').sort_values(by="count",ascending=False)
res
# Out:
#       NTA  count
# 98   MN17  14313
# 95   MN13   7465
# 104  MN24   7152
# 103  MN23   7089
# 106  MN27   5807
# ..    ...    ...
# 47   BK93     91
# 178  SI08     82
# 116  MN99     69
# 87   BX99     55
# 191  SI48     44
#
# [193 rows x 2 columns]

# %%
res = df.groupby(by="CUISINE DESCRIPTION").size().reset_index(name='count').sort_values(by="count",ascending=False)
res
# Out:
#    CUISINE DESCRIPTION  count
# 2             American  41023
# 19             Chinese  24417
# 22          Coffee/Tea  17761
# 67               Pizza  15442
# 53      Latin American  10617
# ..                 ...    ...
# 10              Basque     16
# 80        Southwestern     15
# 26               Czech     13
# 40       Haute Cuisine      5
# 18         Chimichurri      2
#
# [89 rows x 2 columns]
